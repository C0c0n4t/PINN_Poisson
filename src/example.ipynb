# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import random
# Out:
# 2024-09-08 13:17:11.633526: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-08 13:17:11.636811: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-09-08 13:17:11.644886: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-08 13:17:11.658273: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-08 13:17:11.661857: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-09-08 13:17:11.672678: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-08 13:17:12.833689: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
NN = tf.keras.models.Sequential(
    [
        tf.keras.layers.Input((1,)),
        tf.keras.layers.Dense(units=32, activation="tanh"),
        tf.keras.layers.Dense(units=32, activation="tanh"),
        tf.keras.layers.Dense(units=32, activation="tanh"),
        tf.keras.layers.Dense(units=1),
    ]
)

NN.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 32)             │            64 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 32)             │         1,056 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,209 (8.63 KB)
#  Trainable params: 2,209 (8.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
optm = tf.keras.optimizers.Adam(learning_rate=0.001)

# %%
def f(x, y):
    return 1/(x - 1) + 1/(y - 1)

# %%
def ode_system(t, net):
    print(t.shape)
    t = t.reshape(-1, 1)
    print("\n")
    t = tf.constant(t, dtype=tf.float32)
    t_0 = tf.zeros((1, 1))
    one = tf.ones((1, 1))

    with tf.GradientTape() as tape:
        tape.watch(t)

        print(t.shape)
        u = net(t)
        u_t = tape.gradient(u, t)

    ode_loss = u_t - tf.math.cos(2 * np.pi * t)
    IC_loss = net(t_0) - one

    square_loss = tf.square(ode_loss) + tf.square(IC_loss)
    total_loss = tf.reduce_mean(square_loss)

    return total_loss

# %%
train_t = (
    np.array(
        [
            0.0,
            0.025,
            0.475,
            0.5,
            0.525,
            0.9,
            0.95,
            1.0,
            1.05,
            1.1,
            1.4,
            1.45,
            1.5,
            1.55,
            1.6,
            1.95,
            2.0,
        ]
    )
).reshape(-1, 1)
train_loss_record = []

print(NN(train_t))

for itr in range(6000):
    with tf.GradientTape() as tape:
        train_loss = ode_system(train_t, NN)
        train_loss_record.append(train_loss)

        grad_w = tape.gradient(train_loss, NN.trainable_variables)
        optm.apply_gradients(zip(grad_w, NN.trainable_variables))

    if itr % 1000 == 0:
        print(train_loss.numpy())

plt.figure(figsize=(10, 8))
plt.plot(train_loss_record)
plt.show()
# Out:
# tf.Tensor(
# [[0.        ]
#  [0.01446197]
#  [0.26056036]
#  [0.27277955]
#  [0.28479415]
#  [0.43862587]
#  [0.45535448]
#  [0.47122985]
#  [0.4862756 ]
#  [0.5005169 ]
#  [0.5706847 ]
#  [0.58011353]
#  [0.5889747 ]
#  [0.5972967 ]
#  [0.6051075 ]
#  [0.64758074]
#  [0.6521765 ]], shape=(17, 1), dtype=float32)
# (17, 1)
#
#
# (17, 1)
# 1.9455465
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# (17, 1)
#
#
# (17, 1)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 30
#      28 for itr in range(6000):
#      29     with tf.GradientTape() as tape:
# ---> 30         train_loss = ode_system(train_t, NN)
#      31         train_loss_record.append(train_loss)
#      33         grad_w = tape.gradient(train_loss, NN.trainable_variables)
#
# Cell In[6], line 17, in ode_system(t, net)
#      14     u_t = tape.gradient(u, t)
#      16 ode_loss = u_t - tf.math.cos(2 * np.pi * t)
# ---> 17 IC_loss = net(t_0) - one
#      19 square_loss = tf.square(ode_loss) + tf.square(IC_loss)
#      20 total_loss = tf.reduce_mean(square_loss)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/models/sequential.py:212, in Sequential.call(self, inputs, training, mask)
#     210 def call(self, inputs, training=None, mask=None):
#     211     if self._functional:
# --> 212         return self._functional.call(inputs, training=training, mask=mask)
#     214     # Fallback: Just apply the layer sequence.
#     215     # This typically happens if `inputs` is a nested struct.
#     216     for layer in self.layers:
#     217         # During each iteration, `inputs` are the inputs to `layer`, and
#     218         # `outputs` are the outputs of `layer` applied to `inputs`. At the
#     219         # end of each iteration `inputs` is set to `outputs` to prepare for
#     220         # the next layer.
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/models/functional.py:175, in Functional.call(self, inputs, training, mask)
#     173         if mask is not None:
#     174             x._keras_mask = mask
# --> 175 outputs = self._run_through_graph(
#     176     inputs, operation_fn=lambda op: operation_fn(op, training=training)
#     177 )
#     178 return unpack_singleton(outputs)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/ops/function.py:171, in Function._run_through_graph(self, inputs, operation_fn, call_fn)
#     169     outputs = call_fn(op, *args, **kwargs)
#     170 else:
# --> 171     outputs = op(*args, **kwargs)
#     173 # Update tensor_dict.
#     174 for x, y in zip(node.outputs, tree.flatten(outputs)):
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/models/functional.py:560, in operation_fn.<locals>.call(*args, **kwargs)
#     554 if (
#     555     hasattr(operation, "_call_has_training_arg")
#     556     and operation._call_has_training_arg
#     557     and training is not None
#     558 ):
#     559     kwargs["training"] = training
# --> 560 return operation(*args, **kwargs)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/layers/layer.py:901, in Layer.__call__(self, *args, **kwargs)
#     899         outputs = super().__call__(*args, **kwargs)
#     900 else:
# --> 901     outputs = super().__call__(*args, **kwargs)
#     902 # Change the layout for the layer output if needed.
#     903 # This is useful for relayout intermediate tensor in the model
#     904 # to achieve the optimal performance.
#     905 distribution = distribution_lib.distribution()
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/ops/operation.py:46, in Operation.__call__(self, *args, **kwargs)
#      41             call_fn = self.call
#      42     call_fn = traceback_utils.inject_argument_info_in_traceback(
#      43         call_fn,
#      44         object_name=(f"{self.__class__.__name__}.call()"),
#      45     )
# ---> 46     return call_fn(*args, **kwargs)
#      48 # Plain flow.
#      49 if any_symbolic_tensors(args, kwargs):
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:156, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#     154 bound_signature = None
#     155 try:
# --> 156     return fn(*args, **kwargs)
#     157 except Exception as e:
#     158     if hasattr(e, "_keras_call_info_injected"):
#     159         # Only inject info for the innermost failing call
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/layers/core/dense.py:144, in Dense.call(self, inputs, training)
#     143 def call(self, inputs, training=None):
# --> 144     x = ops.matmul(inputs, self.kernel)
#     145     if self.bias is not None:
#     146         x = ops.add(x, self.bias)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/ops/numpy.py:3445, in matmul(x1, x2)
#    3443 if any_symbolic_tensors((x1, x2)):
#    3444     return Matmul().symbolic_call(x1, x2)
# -> 3445 return backend.numpy.matmul(x1, x2)
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/numpy.py:373, in matmul(x1, x2)
#     370     output_type = result_dtype
#     371 else:
#     372     # TODO: Typically, GPU and XLA only support float types
# --> 373     compute_dtype = dtypes.result_type(x1.dtype, x2.dtype, float)
#     374     result_dtype = dtypes.result_type(x1.dtype, x2.dtype)
#     375     output_type = None
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/keras/src/backend/common/dtypes.py:304, in result_type(*dtypes)
#     302     return config.floatx()
#     303 for dtype in dtypes:
# --> 304     if dtype in FLOAT8_TYPES:
#     305         raise ValueError(
#     306             "There is no implicit conversions from float8 dtypes to others."
#     307             f" You must cast it internally. Received: {dtypes}"
#     308         )
#     309 return _lattice_result_type(
#     310     *(config.floatx() if arg is None else arg for arg in dtypes),
#     311 )
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:271, in DType.__eq__(self, other)
#     269 if type(other) != DType:  # pylint: disable=unidiomatic-typecheck
#     270   try:
# --> 271     other = as_dtype(other)
#     272   except TypeError:
#     273     return False
#
# File ~/projectPractice/pinn_puasson/venv/lib/python3.10/site-packages/tensorflow/python/framework/dtypes.py:825, in as_dtype(type_value)
#     793 @tf_export("dtypes.as_dtype", "as_dtype")
#     794 def as_dtype(type_value):
#     795   """Converts the given `type_value` to a `tf.DType`.
#     796
#     797   Inputs can be existing `tf.DType` objects, a [`DataType`
#    (...)
#     823     TypeError: If `type_value` cannot be converted to a `DType`.
#     824   """
# --> 825   if isinstance(type_value, DType):
#     826     if type_value._handle_data is None:  # pylint:disable=protected-access
#     827       return _INTERN_TABLE[type_value.as_datatype_enum]
#
# File /usr/lib/python3.10/abc.py:119, in ABCMeta.__instancecheck__(cls, instance)
#     117 def __instancecheck__(cls, instance):
#     118     """Override for isinstance(instance, cls)."""
# --> 119     return _abc_instancecheck(cls, instance)
#
# KeyboardInterrupt:

# %%
test_t = np.linspace(0, 2, 100)

train_u = np.sin(2 * np.pi * train_t) / (2 * np.pi) + 1
true_u = np.sin(2 * np.pi * test_t) / (2 * np.pi) + 1
pred_u = NN.predict(test_t).ravel()

plt.figure(figsize=(10, 8))
plt.plot(train_t, train_u, "ok", label="Train")
plt.plot(test_t, true_u, "-k", label="True")
plt.plot(test_t, pred_u, "--r", label="Prediction")
plt.legend(fontsize=15)
plt.xlabel("t", fontsize=15)
plt.ylabel("u", fontsize=15)
plt.show()
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
